# %%
import pandas as pd

# %%
streamFeatures = pd.read_csv('Data/BC/athabascaStreamDaily.csv')

# %%
streamFeatures.head(8)
# Out:
#                                ﻿Daily Discharge (m3/s) (PARAM = 1) and Daily Water Level (m) (PARAM = 2)
#  ID     PARAM Date       Value                                                SYM
# 07AA002 1     1913/07/01 257                                                  NaN
#               1913/07/02 280                                                  NaN
#               1913/07/03 218                                                  NaN
#               1913/07/04 194                                                  NaN
#               1913/07/05 221                                                  NaN
#               1913/07/06 194                                                  NaN
#               1913/07/07 328                                                  NaN

# %%
dailyFeatures = pd.read_csv('Data/BC/jasperDaily2011.csv')

# %%
dailyFeatures.head(8)
# Out:
#             x          y  LOCAL_YEAR MEAN_TEMPERATURE_FLAG  LOCAL_MONTH  \
# 0 -118.029722  52.926389        2011                   NaN            7
# 1 -118.029722  52.926389        2011                   NaN            7
# 2 -118.029722  52.926389        2011                   NaN            7
# 3 -118.029722  52.926389        2011                   NaN            7
# 4 -118.029722  52.926389        2011                   NaN            7
# 5 -118.029722  52.926389        2011                   NaN            7
# 6 -118.029722  52.926389        2011                   NaN            7
# 7 -118.029722  52.926389        2011                   NaN            7
#
#    LOCAL_DAY  SPEED_MAX_GUST PROVINCE_CODE HEATING_DEGREE_DAYS_FLAG  \
# 0         10             0.0            AB                      NaN
# 1         11            32.0            AB                      NaN
# 2         12            35.0            AB                      NaN
# ...

# %%
# Specify the column indices to remove (e.g., 0 for 'A', 1 for 'B', etc.)
cols_to_remove = [0, 1, 3, 6, 7, 9, 12, 13, 14, 19, 23, 26, 27, 29, 31, 32, 33, 35]

# Drop columns by index
dailyFeatures = dailyFeatures.drop(dailyFeatures.columns[cols_to_remove], axis=1)

# %%
dailyFeatures.head(8)
# Out:
#    LOCAL_YEAR  LOCAL_MONTH HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY  \
# 0        2011            7                      NaN              48.0
# 1        2011            7                      NaN              42.0
# 2        2011            7                      NaN              43.0
# 3        2011            7                      NaN              38.0
# 4        2011            7                      NaN              33.0
# 5        2011            7                      NaN              39.0
# 6        2011            7                      NaN              24.0
# 7        2011            7                      NaN              22.0
#
#   MIN_REL_HUMIDITY_FLAG TOTAL_SNOW_FLAG  HEATING_DEGREE_DAYS  TOTAL_RAIN  \
# 0                   NaN               M                  3.9         NaN
# 1                   NaN               M                  3.4         NaN
# 2                   NaN               M                  1.6         NaN
# ...

# %%
streamFeatures = streamFeatures.iloc[35806:, 1:]

# %%
streamFeatures.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(07AA002, 1, 2011/07/12, 256), (07AA002, 1, 2011/07/13, 284), (07AA002, 1, 2011/07/14, 286), (07AA002, 1, 2011/07/15, 250), (07AA002, 1, 2011/07/16, 222), (07AA002, 1, 2011/07/17, 227), (07AA002, 1, 2011/07/18, 252), (07AA002, 1, 2011/07/19, 290), (07AA002, 1, 2011/07/20, 281), (07AA002, 1, 2011/07/21, 248)]

# %%
# Load the dataset with correct header row
streamFeatures = pd.read_csv('Data/BC/athabascaStreamDaily.csv', header=1)

# Keep only rows from index 35806 onwards
streamFeatures = streamFeatures.iloc[35805:]

# Remove the first column
streamFeatures = streamFeatures.drop(streamFeatures.columns[0], axis=1)

# Reset index after slicing
streamFeatures = streamFeatures.reset_index(drop=True)

# %%
streamFeatures.head(10)
# Out:
#    PARAM        Date  Value  SYM
# 0      1  2011/07/12  256.0  NaN
# 1      1  2011/07/13  284.0  NaN
# 2      1  2011/07/14  286.0    A
# 3      1  2011/07/15  250.0  NaN
# 4      1  2011/07/16  222.0  NaN
# 5      1  2011/07/17  227.0  NaN
# 6      1  2011/07/18  252.0  NaN
# 7      1  2011/07/19  290.0  NaN
# 8      1  2011/07/20  281.0  NaN
# 9      1  2011/07/21  248.0  NaN

# %%
streamFeatures.to_csv('modified_athabascaStreamDaily.csv', index=False)

# %%
dailyFeatures.to_csv('modified_jasperDaily2011.csv', index=False)

# %%
combined_df = dailyFeatures.join(streamFeatures)

# %%
combined_df.head(5)
# Out:
#    LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY HEATING_DEGREE_DAYS_FLAG  \
# 0        2011            7         10                      NaN
# 1        2011            7         11                      NaN
# 2        2011            7         12                      NaN
# 3        2011            7         13                      NaN
# 4        2011            7         14                      NaN
#
#    MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG TOTAL_SNOW_FLAG  \
# 0              48.0                   NaN               M
# 1              42.0                   NaN               M
# 2              43.0                   NaN               M
# 3              38.0                   NaN               M
# 4              33.0                   NaN               M
#
#    HEATING_DEGREE_DAYS  TOTAL_RAIN  TOTAL_PRECIPITATION  ... MAX_TEMPERATURE  \
# 0                  3.9         NaN                  0.2  ...            19.0
# 1                  3.4         NaN                  0.0  ...            22.4
# ...

# %%
# Save the combined DataFrame to a new file
combined_df.to_csv('combined_columns_file.csv', index=False)

# %%
# Remove columns where all values are NaN
df_cleaned = combined_df.dropna(axis=1, how='all')

# Save the cleaned DataFrame to a new file
df_cleaned.to_csv('cleaned_file.csv', index=False)

# %%
df_cleaned = pd.read_csv('Data/BC/cleaned_file.csv')

# %%
df_cleaned.head(5)
# Out:
#    LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY HEATING_DEGREE_DAYS_FLAG  \
# 0        2011            7         10                      NaN
# 1        2011            7         11                      NaN
# 2        2011            7         12                      NaN
# 3        2011            7         13                      NaN
# 4        2011            7         14                      NaN
#
#    MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG TOTAL_SNOW_FLAG  \
# 0              48.0                   NaN               M
# 1              42.0                   NaN               M
# 2              43.0                   NaN               M
# 3              38.0                   NaN               M
# 4              33.0                   NaN               M
#
#    HEATING_DEGREE_DAYS  TOTAL_RAIN  TOTAL_PRECIPITATION  ...      LOCAL_DATE  \
# 0                  3.9         NaN                  0.2  ...  7/10/2011 0:00
# 1                  3.4         NaN                  0.0  ...  7/11/2011 0:00
# ...
