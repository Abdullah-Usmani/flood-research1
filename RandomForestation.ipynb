# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
streamFeatures = pd.read_csv('athabascaStreamDaily.csv')

# %%
streamFeatures.head(8)
# Out:
#                                ﻿Daily Discharge (m3/s) (PARAM = 1) and Daily Water Level (m) (PARAM = 2)
#  ID     PARAM Date       Value                                                SYM
# 07AA002 1     1913/07/01 257                                                  NaN
#               1913/07/02 280                                                  NaN
#               1913/07/03 218                                                  NaN
#               1913/07/04 194                                                  NaN
#               1913/07/05 221                                                  NaN
#               1913/07/06 194                                                  NaN
#               1913/07/07 328                                                  NaN

# %%
dailyFeatures = pd.read_csv('jasperDaily2011.csv')

# %%
dailyFeatures.head(8)
# Out:
#             x          y  LOCAL_YEAR MEAN_TEMPERATURE_FLAG  LOCAL_MONTH  \
# 0 -118.029722  52.926389        2011                   NaN            7
# 1 -118.029722  52.926389        2011                   NaN            7
# 2 -118.029722  52.926389        2011                   NaN            7
# 3 -118.029722  52.926389        2011                   NaN            7
# 4 -118.029722  52.926389        2011                   NaN            7
# 5 -118.029722  52.926389        2011                   NaN            7
# 6 -118.029722  52.926389        2011                   NaN            7
# 7 -118.029722  52.926389        2011                   NaN            7
#
#    LOCAL_DAY  SPEED_MAX_GUST PROVINCE_CODE HEATING_DEGREE_DAYS_FLAG  \
# 0         10             0.0            AB                      NaN
# 1         11            32.0            AB                      NaN
# 2         12            35.0            AB                      NaN
# ...

# %%
# Specify the column indices to remove (e.g., 0 for 'A', 1 for 'B', etc.)
cols_to_remove = [0, 1, 3, 6, 7, 9, 12, 13, 14, 19, 23, 26, 27, 29, 31, 32, 33, 35]

# Drop columns by index
dailyFeatures = dailyFeatures.drop(dailyFeatures.columns[cols_to_remove], axis=1)

# %%
dailyFeatures.head(8)
# Out:
#    LOCAL_YEAR  LOCAL_MONTH HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY  \
# 0        2011            7                      NaN              48.0
# 1        2011            7                      NaN              42.0
# 2        2011            7                      NaN              43.0
# 3        2011            7                      NaN              38.0
# 4        2011            7                      NaN              33.0
# 5        2011            7                      NaN              39.0
# 6        2011            7                      NaN              24.0
# 7        2011            7                      NaN              22.0
#
#   MIN_REL_HUMIDITY_FLAG TOTAL_SNOW_FLAG  HEATING_DEGREE_DAYS  TOTAL_RAIN  \
# 0                   NaN               M                  3.9         NaN
# 1                   NaN               M                  3.4         NaN
# 2                   NaN               M                  1.6         NaN
# ...

# %%
streamFeatures = streamFeatures.iloc[35806:, 1:]

# %%
streamFeatures.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(07AA002, 1, 2011/07/12, 256), (07AA002, 1, 2011/07/13, 284), (07AA002, 1, 2011/07/14, 286), (07AA002, 1, 2011/07/15, 250), (07AA002, 1, 2011/07/16, 222), (07AA002, 1, 2011/07/17, 227), (07AA002, 1, 2011/07/18, 252), (07AA002, 1, 2011/07/19, 290), (07AA002, 1, 2011/07/20, 281), (07AA002, 1, 2011/07/21, 248)]

# %%
# Load the dataset with correct header row
streamFeatures = pd.read_csv('athabascaStreamDaily.csv', header=1)

# Keep only rows from index 35806 onwards
streamFeatures = streamFeatures.iloc[35805:]

# Remove the first column
streamFeatures = streamFeatures.drop(streamFeatures.columns[0], axis=1)

# Reset index after slicing
streamFeatures = streamFeatures.reset_index(drop=True)

# %%
streamFeatures.head(10)
# Out:
#    PARAM        Date  Value  SYM
# 0      1  2011/07/12  256.0  NaN
# 1      1  2011/07/13  284.0  NaN
# 2      1  2011/07/14  286.0    A
# 3      1  2011/07/15  250.0  NaN
# 4      1  2011/07/16  222.0  NaN
# 5      1  2011/07/17  227.0  NaN
# 6      1  2011/07/18  252.0  NaN
# 7      1  2011/07/19  290.0  NaN
# 8      1  2011/07/20  281.0  NaN
# 9      1  2011/07/21  248.0  NaN

# %%
streamFeatures.to_csv('modified_athabascaStreamDaily.csv', index=False)

# %%
dailyFeatures.to_csv('modified_jasperDaily2011.csv', index=False)

# %%
combined_df = dailyFeatures.join(streamFeatures)

# %%
combined_df.head(5)
# Out:
#    LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY HEATING_DEGREE_DAYS_FLAG  \
# 0        2011            7         10                      NaN
# 1        2011            7         11                      NaN
# 2        2011            7         12                      NaN
# 3        2011            7         13                      NaN
# 4        2011            7         14                      NaN
#
#    MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG TOTAL_SNOW_FLAG  \
# 0              48.0                   NaN               M
# 1              42.0                   NaN               M
# 2              43.0                   NaN               M
# 3              38.0                   NaN               M
# 4              33.0                   NaN               M
#
#    HEATING_DEGREE_DAYS  TOTAL_RAIN  TOTAL_PRECIPITATION  ... MAX_TEMPERATURE  \
# 0                  3.9         NaN                  0.2  ...            19.0
# 1                  3.4         NaN                  0.0  ...            22.4
# ...

# %%
# Save the combined DataFrame to a new file
combined_df.to_csv('combined_columns_file.csv', index=False)

# %%
# Remove columns where all values are NaN
df_cleaned = combined_df.dropna(axis=1, how='all')

# Save the cleaned DataFrame to a new file
df_cleaned.to_csv('cleaned_file.csv', index=False)

# %%
df_cleaned = pd.read_csv('cleaned_file.csv')

# %%
df_cleaned.head(5)
# Out:
#    LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY HEATING_DEGREE_DAYS_FLAG  \
# 0      2011.0          7.0       10.0                      NaN
# 1      2011.0          7.0       11.0                      NaN
# 2      2011.0          7.0       12.0                      NaN
# 3      2011.0          7.0       13.0                      NaN
# 4      2011.0          7.0       14.0                      NaN
#
#    MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG TOTAL_SNOW_FLAG  \
# 0              48.0                   NaN               M
# 1              42.0                   NaN               M
# 2              43.0                   NaN               M
# 3              38.0                   NaN               M
# 4              33.0                   NaN               M
#
#    HEATING_DEGREE_DAYS  TOTAL_RAIN  TOTAL_PRECIPITATION  ...      LOCAL_DATE  \
# 0                  3.9         NaN                  0.2  ...  7/10/2011 0:00
# 1                  3.4         NaN                  0.0  ...  7/11/2011 0:00
# ...

# %%
df_cleaned.drop(df_cleaned.columns[[0,1,2]], axis=1)
# Out:
#      HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY MIN_REL_HUMIDITY_FLAG  \
# 0                         NaN              48.0                   NaN
# 1                         NaN              42.0                   NaN
# 2                         NaN              43.0                   NaN
# 3                         NaN              38.0                   NaN
# 4                         NaN              33.0                   NaN
# ...                       ...               ...                   ...
# 4759                      NaN               NaN                   NaN
# 4760                      NaN               NaN                   NaN
# 4761                      NaN               NaN                   NaN
# 4762                      NaN               NaN                   NaN
# 4763                      NaN               NaN                   NaN
#
#      TOTAL_SNOW_FLAG  HEATING_DEGREE_DAYS  TOTAL_RAIN  TOTAL_PRECIPITATION  \
# ...

# %%
df_cleaned = df_cleaned.set_index('ID')

# %%
df_cleaned.head(5)
# Out:
#                   HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY  \
# ID
# 3053536.2011.7.10                      NaN              48.0
# 3053536.2011.7.11                      NaN              42.0
# 3053536.2011.7.12                      NaN              43.0
# 3053536.2011.7.13                      NaN              38.0
# 3053536.2011.7.14                      NaN              33.0
#
#                   MIN_REL_HUMIDITY_FLAG TOTAL_SNOW_FLAG  HEATING_DEGREE_DAYS  \
# ID
# 3053536.2011.7.10                   NaN               M                  3.9
# 3053536.2011.7.11                   NaN               M                  3.4
# 3053536.2011.7.12                   NaN               M                  1.6
# 3053536.2011.7.13                   NaN               M                  1.4
# 3053536.2011.7.14                   NaN               M                  4.7
#
#                    TOTAL_RAIN  TOTAL_PRECIPITATION      LOCAL_DATE  \
# ID
# ...

# %%
df_cleaned = df_cleaned.drop(df_cleaned.columns[[0,1,2]], axis=1)

# %%
df_cleaned.to_csv('refined_file.csv', index=True)

# %%
df1 = pd.read_csv('refined_file.csv')

# %%
df1.head(5)
# Out:
#                   HEATING_DEGREE_DAYS_FLAG  MIN_REL_HUMIDITY  \
# ID
# 3053536.2011.7.10                      NaN              48.0
# 3053536.2011.7.11                      NaN              42.0
# 3053536.2011.7.12                      NaN              43.0
# 3053536.2011.7.13                      NaN              38.0
# 3053536.2011.7.14                      NaN              33.0
#
#                   MIN_REL_HUMIDITY_FLAG TOTAL_SNOW_FLAG  HEATING_DEGREE_DAYS  \
# ID
# 3053536.2011.7.10                   NaN               M                  3.9
# 3053536.2011.7.11                   NaN               M                  3.4
# 3053536.2011.7.12                   NaN               M                  1.6
# 3053536.2011.7.13                   NaN               M                  1.4
# 3053536.2011.7.14                   NaN               M                  4.7
#
#                    TOTAL_RAIN  TOTAL_PRECIPITATION      LOCAL_DATE  \
# ID
# ...

# %%
df1 = df1.set_index('ID')

# %%
# Sort the columns alphabetically
df_sorted = df1.sort_index(axis=1)

# %%
df_sorted.head(5)
# Out:
#                    COOLING_DEGREE_DAYS       Date  HEATING_DEGREE_DAYS  \
# ID
# 3053536.2011.7.10                  0.0  7/10/2011                  3.9
# 3053536.2011.7.11                  0.0  7/11/2011                  3.4
# 3053536.2011.7.12                  0.0  7/12/2011                  1.6
# 3053536.2011.7.13                  0.0  7/13/2011                  1.4
# 3053536.2011.7.14                  0.0  7/14/2011                  4.7
#
#                   HEATING_DEGREE_DAYS_FLAG      LOCAL_DATE  MAX_REL_HUMIDITY  \
# ID
# 3053536.2011.7.10                      NaN  7/10/2011 0:00              95.0
# 3053536.2011.7.11                      NaN  7/11/2011 0:00              97.0
# 3053536.2011.7.12                      NaN  7/12/2011 0:00              91.0
# 3053536.2011.7.13                      NaN  7/13/2011 0:00              96.0
# 3053536.2011.7.14                      NaN  7/14/2011 0:00              98.0
#
# ...

# %%
df_sorted.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df_sorted.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df = pd.read_csv('jasperDaily2011_cleansed.csv')

# %%
print(df.shape)
# Out:
# (4761, 19)

# %%
df.describe()
# Out:
#        DIRECTION_MAX_GUST  SPEED_MAX_GUST  SNOW_ON_GROUND  TOTAL_RAIN  \
# count         3263.000000     3265.000000     1777.000000        25.0
# mean            11.842476       18.904135       14.747890         0.0
# std             13.437995       19.367313       12.334833         0.0
# min              0.000000        0.000000        0.000000         0.0
# 25%              0.000000        0.000000        2.000000         0.0
# 50%              1.000000       31.000000       15.000000         0.0
# 75%             22.000000       36.000000       23.000000         0.0
# max             36.000000       77.000000       80.000000         0.0
#
#        TOTAL_PRECIPITATION  TOTAL_SNOW  HEATING_DEGREE_DAYS  \
# count          4468.000000         0.0          4491.000000
# mean              1.025269         NaN            14.502538
# std               3.181846         NaN            10.273180
# min               0.000000         NaN             0.000000
# ...

# %%
# Linearly interpolate missing values in specific columns
# For example, interpolate missing values in 'Column1' and 'Column2'
df['TOTAL_PRECIPITATION'] = df['TOTAL_PRECIPITATION'].interpolate(method='linear')
df['HEATING_DEGREE_DAYS'] = df['HEATING_DEGREE_DAYS'].interpolate(method='linear')
df['COOLING_DEGREE_DAYS'] = df['COOLING_DEGREE_DAYS'].interpolate(method='linear')
df['MIN_REL_HUMIDITY'] = df['MIN_REL_HUMIDITY'].interpolate(method='linear')
df['MAX_REL_HUMIDITY'] = df['MAX_REL_HUMIDITY'].interpolate(method='linear')
df['MAX_TEMPERATURE'] = df['MAX_TEMPERATURE'].interpolate(method='linear')
df['MEAN_TEMPERATURE'] = df['MEAN_TEMPERATURE'].interpolate(method='linear')
df['MIN_TEMPERATURE'] = df['MIN_TEMPERATURE'].interpolate(method='linear')

# %%
df.describe()
# Out:
#        DIRECTION_MAX_GUST  SPEED_MAX_GUST  SNOW_ON_GROUND  TOTAL_RAIN  \
# count         3263.000000     3265.000000     1777.000000        25.0
# mean            11.842476       18.904135       14.747890         0.0
# std             13.437995       19.367313       12.334833         0.0
# min              0.000000        0.000000        0.000000         0.0
# 25%              0.000000        0.000000        2.000000         0.0
# 50%              1.000000       31.000000       15.000000         0.0
# 75%             22.000000       36.000000       23.000000         0.0
# max             36.000000       77.000000       80.000000         0.0
#
#        TOTAL_PRECIPITATION  TOTAL_SNOW  HEATING_DEGREE_DAYS  \
# count          4761.000000         0.0          4761.000000
# mean              0.997543         NaN            14.605934
# std               3.240159         NaN            10.053083
# min               0.000000         NaN             0.000000
# ...

# %%
df.to_csv('interpolated_file.csv', index=False)

# %%
df = pd.read_csv('interpolated_file.csv')

# %%
df.head(3)
# Out:
#                   ID      LOCAL_DATE  DIRECTION_MAX_GUST  SPEED_MAX_GUST  \
# 0  3053536.2011.7.10  7/10/2011 0:00                 0.0             0.0
# 1  3053536.2011.7.11  7/11/2011 0:00                34.0            32.0
# 2  3053536.2011.7.12  7/12/2011 0:00                33.0            35.0
#
#    SNOW_ON_GROUND  TOTAL_RAIN  TOTAL_PRECIPITATION  TOTAL_SNOW  \
# 0             NaN         NaN                  0.2         NaN
# 1             NaN         NaN                  0.0         NaN
# 2             NaN         NaN                  0.0         NaN
#
#    HEATING_DEGREE_DAYS  COOLING_DEGREE_DAYS  MIN_REL_HUMIDITY  \
# 0                  3.9                  0.0              48.0
# 1                  3.4                  0.0              42.0
# 2                  1.6                  0.0              43.0
#
#    MAX_REL_HUMIDITY  MAX_TEMPERATURE  MEAN_TEMPERATURE  MIN_TEMPERATURE  \
# 0              95.0             19.0              14.1              9.1
# ...

# %%
# Select columns 2-6 (Note: Python uses zero-based indexing, so column 2 is df.columns[1])
columns_to_plot = pd.concat([df.iloc[:, 2:14], df.iloc[:, 17:18]], axis=1)

# Loop through each selected column and plot it
for column in columns_to_plot.columns:
    if pd.api.types.is_numeric_dtype(columns_to_plot[column]):
        plt.figure(figsize=(10, 5))  # Set the figure size
        plt.plot(df.index, columns_to_plot[column], marker='o')  # Plot each column as a line graph
        plt.title(f'Line Graph for {column}')  # Title with the column name
        plt.xlabel('Index')  # Label for the x-axis
        plt.ylabel(column)  # Label for the y-axis
        plt.grid(True)  # Add a grid for better readability
        plt.show()  # Display the plot
    else:
        print(f"Skipping column {column} as it is not numeric.")

# %%
df1 = pd.read_csv('jasperDaily2011_cleansed.csv')
# Select columns 2-6 (Note: Python uses zero-based indexing, so column 2 is df.columns[1])
columns_to_plot = pd.concat([df1.iloc[:, 2:14], df1.iloc[:, 17:18]], axis=1)

# Loop through each selected column and plot it
for column in columns_to_plot.columns:
    if pd.api.types.is_numeric_dtype(columns_to_plot[column]):
        plt.figure(figsize=(10, 5))  # Set the figure size
        plt.plot(df1.index, columns_to_plot[column], marker='o')  # Plot each column as a line graph
        plt.title(f'Line Graph for {column}')  # Title with the column name
        plt.xlabel('Index')  # Label for the x-axis
        plt.ylabel(column)  # Label for the y-axis
        plt.grid(True)  # Add a grid for better readability
        plt.show()  # Display the plot
    else:
        print(f"Skipping column {column} as it is not numeric.")

# %%
# Best to keep these for interpol, not Humid cuz that has a massive gap of missing vals
df1['TOTAL_PRECIPITATION'] = df1['TOTAL_PRECIPITATION'].interpolate(method='linear')
df1['HEATING_DEGREE_DAYS'] = df1['HEATING_DEGREE_DAYS'].interpolate(method='linear')
df1['COOLING_DEGREE_DAYS'] = df1['COOLING_DEGREE_DAYS'].interpolate(method='linear')
df1['MAX_TEMPERATURE'] = df1['MAX_TEMPERATURE'].interpolate(method='linear')
df1['MEAN_TEMPERATURE'] = df1['MEAN_TEMPERATURE'].interpolate(method='linear')
df1['MIN_TEMPERATURE'] = df1['MIN_TEMPERATURE'].interpolate(method='linear')

# %%
df1.to_csv('interpolated_file2.csv', index=False)

# %%
df = pd.read_csv('interpolated_file2.csv')

# %%
# Specify the columns to drop
columns_to_drop = ['ID', 'TOTAL_RAIN', 'TOTAL_SNOW']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# Print the DataFrame
print(df)

# %%
# Specify the columns to drop
columns_to_drop = ['Date']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# Print the DataFrame
print(df)
# Out:
#           LOCAL_DATE  DIRECTION_MAX_GUST  SPEED_MAX_GUST  SNOW_ON_GROUND  \
# 0     7/10/2011 0:00                 0.0             0.0             NaN
# 1     7/11/2011 0:00                34.0            32.0             NaN
# 2     7/12/2011 0:00                33.0            35.0             NaN
# 3     7/13/2011 0:00                 0.0             0.0             NaN
# 4     7/14/2011 0:00                19.0            32.0             NaN
# ...              ...                 ...             ...             ...
# 4756             NaN                 NaN             NaN             NaN
# 4757             NaN                 NaN             NaN             NaN
# 4758             NaN                 NaN            45.0             NaN
# 4759             NaN                 NaN             NaN             NaN
# 4760             NaN                 NaN            33.0             NaN
#
#       TOTAL_PRECIPITATION  HEATING_DEGREE_DAYS  COOLING_DEGREE_DAYS  \
# ...

# %%
df.to_csv('interpolated_file3.csv', index=False)

# %%
df = pd.read_csv('interpolated_file3.csv')
df.head(5)
# Out:
#        LOCAL_DATE  DIRECTION_MAX_GUST  SPEED_MAX_GUST  SNOW_ON_GROUND  \
# 0  7/10/2011 0:00                 0.0             0.0             NaN
# 1  7/11/2011 0:00                34.0            32.0             NaN
# 2  7/12/2011 0:00                33.0            35.0             NaN
# 3  7/13/2011 0:00                 0.0             0.0             NaN
# 4  7/14/2011 0:00                19.0            32.0             NaN
#
#    TOTAL_PRECIPITATION  HEATING_DEGREE_DAYS  COOLING_DEGREE_DAYS  \
# 0                  0.2                  3.9                  0.0
# 1                  0.0                  3.4                  0.0
# 2                  0.0                  1.6                  0.0
# 3                  2.1                  1.4                  0.0
# 4                  0.3                  4.7                  0.0
#
#    MIN_REL_HUMIDITY  MAX_REL_HUMIDITY  MAX_TEMPERATURE  MEAN_TEMPERATURE  \
# 0              48.0              95.0             19.0              14.1
# ...

# %%
df['LOCAL_DATE'] = pd.to_datetime(df['LOCAL_DATE'])

# %%
df.set_index('LOCAL_DATE', inplace=True)

# %%
print(df.shape)
# Out:
# (4761, 14)

# %%
columns_to_plot = df.iloc[:, 0:13]

# Loop through each selected column and plot it
for column in columns_to_plot.columns:
    if pd.api.types.is_numeric_dtype(columns_to_plot[column]):
        plt.figure(figsize=(10, 5))  # Set the figure size
        plt.plot(df.index, columns_to_plot[column], marker='o')  # Plot each column as a line graph
        plt.title(f'Line Graph for {column}')  # Title with the column name
        plt.xlabel('Date')  # Label for the x-axis
        plt.ylabel(column)  # Label for the y-axis
        plt.grid(True)  # Add a grid for better readability
        plt.show()  # Display the plot
    else:
        print(f"Skipping column {column} as it is not numeric.")

# %%
df.to_csv('interpolated_file4.csv', index=True)

# %%
df = pd.read_csv('interpolated_file4.csv')

# %%
df.head(5)
# Out:
#    LOCAL_DATE  DIRECTION_MAX_GUST  SPEED_MAX_GUST  SNOW_ON_GROUND  \
# 0  2011-07-10                 0.0             0.0             NaN
# 1  2011-07-11                34.0            32.0             NaN
# 2  2011-07-12                33.0            35.0             NaN
# 3  2011-07-13                 0.0             0.0             NaN
# 4  2011-07-14                19.0            32.0             NaN
#
#    TOTAL_PRECIPITATION  HEATING_DEGREE_DAYS  COOLING_DEGREE_DAYS  \
# 0                  0.2                  3.9                  0.0
# 1                  0.0                  3.4                  0.0
# 2                  0.0                  1.6                  0.0
# 3                  2.1                  1.4                  0.0
# 4                  0.3                  4.7                  0.0
#
#    MIN_REL_HUMIDITY  MAX_REL_HUMIDITY  MAX_TEMPERATURE  MEAN_TEMPERATURE  \
# 0              48.0              95.0             19.0              14.1
# ...
